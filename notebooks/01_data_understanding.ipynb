# %%
import pandas as pd
import numpy as np
import os
import zipfile

# %%
import os
import zipfile

zip_path = "../data/student_resource.zip"

if not os.path.exists("../data/student_resource/dataset/train.csv"):
    with zipfile.ZipFile(zip_path, "r") as zip_ref:
        zip_ref.extractall("../data")
    print("Dataset extracted.")
else:
    print("Dataset already extracted.")
# Out:
# Dataset already extracted.

# %%
for root, dirs, files in os.walk("../data/student_resource"):
    for file in files:
        print(os.path.join(root, file))
# Out:
# ../data/student_resource\.DS_Store
# ../data/student_resource\Documentation_template.md
# ../data/student_resource\README.md
# ../data/student_resource\sample_code.py
# ../data/student_resource\dataset\sample_test.csv
# ../data/student_resource\dataset\sample_test_out.csv
# ../data/student_resource\dataset\test.csv
# ../data/student_resource\dataset\train.csv
# ../data/student_resource\extracted\student_resource\.DS_Store
# ../data/student_resource\extracted\student_resource\Documentation_template.md
# ../data/student_resource\extracted\student_resource\README.md
# ../data/student_resource\extracted\student_resource\sample_code.py
# ../data/student_resource\extracted\student_resource\dataset\sample_test.csv
# ../data/student_resource\extracted\student_resource\dataset\sample_test_out.csv
# ../data/student_resource\extracted\student_resource\dataset\test.csv
# ../data/student_resource\extracted\student_resource\dataset\train.csv
# ...

# %%
csv_files = []

for root, dirs, files in os.walk("../data/student_resource"):
    for file in files:
        if file.endswith(".csv"):
            csv_files.append(os.path.join(root, file))

print("CSV Files Found:")
for file in csv_files:
    print(file)
# Out:
# CSV Files Found:
# ../data/student_resource\dataset\sample_test.csv
# ../data/student_resource\dataset\sample_test_out.csv
# ../data/student_resource\dataset\test.csv
# ../data/student_resource\dataset\train.csv
# ../data/student_resource\extracted\student_resource\dataset\sample_test.csv
# ../data/student_resource\extracted\student_resource\dataset\sample_test_out.csv
# ../data/student_resource\extracted\student_resource\dataset\test.csv
# ../data/student_resource\extracted\student_resource\dataset\train.csv
# ../data/student_resource\extracted\__MACOSX\student_resource\dataset\._sample_test.csv
# ../data/student_resource\extracted\__MACOSX\student_resource\dataset\._sample_test_out.csv
# ../data/student_resource\extracted\__MACOSX\student_resource\dataset\._test.csv
# ../data/student_resource\extracted\__MACOSX\student_resource\dataset\._train.csv

# %%
train_df = pd.read_csv(
    "../data/student_resource/dataset/train.csv"
)

# %%
train_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 75000 entries, 0 to 74999
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sample_id        75000 non-null  int64
#  1   catalog_content  75000 non-null  str
#  2   image_link       75000 non-null  str
#  3   price            75000 non-null  float64
# dtypes: float64(1), int64(1), str(2)
# memory usage: 71.2 MB

# %%
train_df.isnull().sum()
# Out:
# sample_id          0
# catalog_content    0
# image_link         0
# price              0
# dtype: int64

# %%
print("Shape:", train_df.shape)

print("\nColumns:")
print(train_df.columns.tolist())
# Out:
# Shape: (75000, 4)
#
# Columns:
# ['sample_id', 'catalog_content', 'image_link', 'price']
